# %%
age_list = [24, 25, 26, 27, 28]
print(age_list)
# Out:
# [24, 25, 26, 27, 28]

# %%
name_list = ["Ram", "Sita", "Ravi", "Gita", "Kumar"]
print(name_list)
# Out:
# ['Ram', 'Sita', 'Ravi', 'Gita', 'Kumar']

# %%
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Ram', 'Sita', 'Ravi', 'Gita', 'Kumar', 'Yazhini']

# %%
age_list.insert(2, 30)
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
name_list.remove("Yazhini")
print(name_list)
# Out:
# ['Ram', 'Sita', 'Ravi', 'Gita', 'Kumar']

# %%
age_list.pop()
print(age_list)
# Out:
# [24, 25, 30, 26, 27]

# %%
age_list.extend([29, 30, 26])
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %%
age_list.sort(reverse=True)
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
max_age = max(age_list)
min_age = min(age_list)
total_sum = sum(age_list)

print("Max age:", max_age)
print("Min age:", min_age)
print("Sum of ages:", total_sum)
# Out:
# Max age: 30
# Min age: 24
# Sum of ages: 217

# %%
print("First element:", name_list[0])
# Out:
# First element: Ram

# %%
print("Last element:", name_list[-1])
# Out:
# Last element: Kumar

# %%
print("Elements index 2 to 4:", name_list[2:5])
# Out:
# Elements index 2 to 4: ['Ravi', 'Gita', 'Kumar']

# %%
print("Reversed list:", name_list[::-1])
# Out:
# Reversed list: ['Kumar', 'Gita', 'Ravi', 'Sita', 'Ram']

# %%
student_marks = {
    "Arun": 85,
    "Bala": 90,
    "Chitra": 75,
    "Divya": 95,
    "Eshwar": 60
}
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 90, 'Chitra': 75, 'Divya': 95, 'Eshwar': 60}

# %%
print("Mark of Bala:", student_marks["Bala"])
# Out:
# Mark of Bala: 90

# %%
student_marks["Janani"] = 80
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 90, 'Chitra': 75, 'Divya': 95, 'Eshwar': 60, 'Janani': 80}

# %%
student_marks["Arun"] = 82
print(student_marks)
# Out:
# {'Arun': 82, 'Bala': 90, 'Chitra': 75, 'Divya': 95, 'Eshwar': 60, 'Janani': 80}

# %%
print("Keys:", student_marks.keys())
print("Values:", student_marks.values())
print("Key-Value Pairs:", student_marks.items())
# Out:
# Keys: dict_keys(['Arun', 'Bala', 'Chitra', 'Divya', 'Eshwar', 'Janani'])
# Values: dict_values([82, 90, 75, 95, 60, 80])
# Key-Value Pairs: dict_items([('Arun', 82), ('Bala', 90), ('Chitra', 75), ('Divya', 95), ('Eshwar', 60), ('Janani', 80)])

# %%
my_set = set(['a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'])
print(my_set)
my_set[4] = 's'
print(my_set)
# Out:
# {'o', 'e', 'a', 'i', 'u'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 my_set = set(['a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'])
#       2 print(my_set)
# ----> 3 my_set[4] = 's'
#       4 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %%
set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}
union_set = set1.union(set2)
print("Union:", union_set)
intersection_set = set1.intersection(set2)
print("Intersection:", intersection_set)
# Out:
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}

# %%
score = float(input("Enter your score (0 to 10): "))

if score > 7 and score <= 10:
    print("Above Average: Excellent performance! Keep up the good work.")
elif score >= 4 and score <= 7:
    print("Average: Good effort! Keep practicing, there's room for improvement.")
elif score >= 0 and score < 4:
    print("Below Average: Need to improve your performance, consistent practice will lead to better results.")
else:
    print("Invalid score! Please enter a value between 0 and 10.")
# Out:
# Enter your score (0 to 10):  10
# Above Average: Excellent performance! Keep up the good work.
